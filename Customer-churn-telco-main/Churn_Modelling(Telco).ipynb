# %% [markdown]
# # Customer Churn Prediction Model

# %% [markdown]
# # _Customer Churn Prediction Modelling_
#
# ## _TABLE OF CONTENTS_
# * __1.0 OVERVIEW__
# * 1.1 Dataset Description
# * __2.0 DATA PREPARATION__
# * 2.1 Replace empty spaces with np.nan
# * 2.2 Duplicate Check
# * 2.3 Missing Value Check
# * 2.4 Label Encoder
# * 2.5 Data Scalling
# * 3.0 __Model Building__
# * 3.1 Train Test Split
# * 3.2 PyCaret
# * 3.3 Optuna
# * 3.4 Training model
# * 3.5 Saving Model

# %%
#  mounting drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install --quiet optuna
# !pip install --quiet pycaret

# %%
#  Importing libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split


from pycaret.classification import *
import optuna


from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

import pickle

# %% [markdown]
# ## 1. 0 Overview
# The telecom or telecommunications industry is rapidly evolving and is among the fastest-growing industries. With the rising competition, it is more crucial than ever for telecom companies to retain their customers. Predicting customer churn, which is the probability of a customer leaving a company, has become a critical task for telecom companies.
#
# The Telco Churn Prediction dataset provided by IBM includes a sample of customer data with attributes such as customer services, account information, and demographics. The dataset also features a binary label indicating whether the customer has churned or not. The dataset's objective is to predict whether a customer is likely to churn based on their subscribed services and profile.
#
# By analyzing customer data and developing retention strategies, telecom companies can retain their customers and attract new ones from their competitors. In this regard, machine learning models can be used to predict churn and identify the most significant features that contribute to customer churn. This can aid telecom companies in developing targeted customer retention programs and enhancing their business performance.
#
# Algorithm used

# %%
#  Reading dataset into memory
filepath = '/content/gdrive/MyDrive/Telco Customer Churn/datasets/WA_Fn-UseC_-Telco-Customer-Churn.csv'
data0 = pd.read_csv(filepath)

pd.set_option('display.max_columns', None)
data0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data0.shape
# Out:
# (7043, 21)

# %% [markdown]
# ### 1.1 Dataset Description
# The dataset for this project was sourced from [kaggle.com](https://www.kaggle.com/datasets/blastchar/telco-customer-churn?datasetId=13996&language=Python). The dataset contains information 7043 instances (customers, in this case) across 20 different attributes ranging from customer ID to TotalCharges.
#
# #### Definition of Attributes
#     1) customerID : Customer ID
#
#     2) gender : Whether the customer is a male or a female
#
#     3) SeniorCitizen : Whether the customer is a senior citizen or not (1, 0)
#
#     4) Partner : Whether the customer has a partner or not (Yes, No)
#
#     5) Dependents : Whether the customer has dependents or not (Yes, No)
#
#     6) tenure : Number of months the customer has stayed with the company
#
#     7) PhoneService : Whether the customer has a phone service or not (Yes, No)
#
#     8) MultipleLines : Whether the customer has multiple lines or not (Yes, No, No phone service)
#
#     9) InternetService : Customer’s internet service provider (DSL, Fiber optic, No)
#
#     10) OnlineSecurity : Whether the customer has online security or not (Yes, No, No internet service)
#
#     11) OnlineBackup : Whether the customer has online backup or not (Yes, No, No internet service)
#
#     12) DeviceProtection : Whether the customer has device protection or not (Yes, No, No internet service)
#
#     13) TechSupport : Whether the customer has tech support or not (Yes, No, No internet service)
#
#     14) StreamingTV : Whether the customer has streaming TV or not (Yes, No, No internet service)
#
#     15) StreamingMovies : Whether the customer has streaming movies or not (Yes, No, No internet service)
#
#     16) Contract : The contract term of the customer (Month-to-month, One year, Two year)
#
#     17) PaperlessBilling : Whether the customer has paperless billing or not (Yes, No)
#
#     18) PaymentMethod : The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
#
#     19) MonthlyCharges : The amount charged to the customer monthly
#
#     20) TotalCharges : The total amount charged to the customer
#
#     21) Churn : Whether the customer churned or not (Yes or No)

# %%
#  Displaying preview
data0.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
data1 = data0.copy()

# %% [markdown]
# ## 2.0 Data Preparation
# Data preparation took place in 5 steps;
#
#
# ### 2.1 Replace empty spaces with np.nan.

# %%
data1.loc[data1['TotalCharges'] == ' ', 'TotalCharges'] = np.nan
data1['TotalCharges'] = data1['TotalCharges'].astype(float)
data1['TotalCharges'].fillna(data1['TotalCharges'].mean(), inplace=True)

# %% [markdown]
# ### 2.2 Duplication Check

# %%
#  Checking dataset for duplicates
if data1.duplicated().sum() > 0:
    print(f'There are/is duplicates in this dataset\nNumber: {data1.duplicated().sum()}')
else:
    print('Dataset contains no duplicates')
# Out:
# Dataset contains no duplicates

# %% [markdown]
# ### 2.3 Missing Value Check

# %%
#  Checking for missing values
if data1.isnull().sum().sum() > 0:
    print(f'There are/is {data1.isnull().sum().sum()} missing values in this dataset')
else:
    print('There are no missing values in this dataset')
# Out:
# There are no missing values in this dataset

# %%
data2 = data1.copy()

customerID = data2['customerID']

data2 = data2.drop(['customerID'], axis=1)

# %% [markdown]
# ### 2.4 Label Encoder

# %%
data3 = data2.copy()

# %%
def label_encode_features(df):

    # Identify categorical columns
    cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

    # Copy the input dataframe
    encoded_df = df.copy()

    # Encode categorical columns using LabelEncoder
    le = LabelEncoder()
    for col in cat_cols:
        encoded_df[col] = le.fit_transform(encoded_df[col])
        print(f'{col}: {len(encoded_df[col].unique())} unique value(s)')
        print(f'Unique values: {list(encoded_df[col].unique())}\n')

    return encoded_df

# %%
data3 = label_encode_features(data3)
# Out:
# gender: 2 unique value(s)
# Unique values: [0, 1]
#
# Partner: 2 unique value(s)
# Unique values: [1, 0]
#
# Dependents: 2 unique value(s)
# Unique values: [0, 1]
#
# PhoneService: 2 unique value(s)
# Unique values: [0, 1]
#
# MultipleLines: 3 unique value(s)
# Unique values: [1, 0, 2]
#
# InternetService: 3 unique value(s)
# Unique values: [0, 1, 2]
#
# OnlineSecurity: 3 unique value(s)
# Unique values: [0, 2, 1]
#
# OnlineBackup: 3 unique value(s)
# Unique values: [2, 0, 1]
#
# DeviceProtection: 3 unique value(s)
# Unique values: [0, 2, 1]
#
# TechSupport: 3 unique value(s)
# Unique values: [0, 2, 1]
#
# StreamingTV: 3 unique value(s)
# Unique values: [0, 2, 1]
#
# StreamingMovies: 3 unique value(s)
# Unique values: [0, 2, 1]
#
# Contract: 3 unique value(s)
# Unique values: [0, 1, 2]
#
# PaperlessBilling: 2 unique value(s)
# Unique values: [1, 0]
#
# PaymentMethod: 4 unique value(s)
# Unique values: [2, 3, 0, 1]
#
# Churn: 2 unique value(s)
# Unique values: [0, 1]

# %% [markdown]
# ### 2.5 Scalling

# %%
data4 = data3.copy()
scaler = MinMaxScaler()

# Scale the data
scaled_data = scaler.fit_transform(data4)
scaled_data
# Out:
# array([[0.        , 0.        , 1.        , ..., 0.11542289, 0.0012751 ,
#         0.        ],
#        [1.        , 0.        , 0.        , ..., 0.38507463, 0.21586661,
#         0.        ],
#        [1.        , 0.        , 0.        , ..., 0.35422886, 0.01031041,
#         1.        ],
#        ...,
#        [0.        , 0.        , 1.        , ..., 0.11293532, 0.03780868,
#         0.        ],
#        [1.        , 1.        , 1.        , ..., 0.55870647, 0.03321025,
#         1.        ],
#        [1.        , 0.        , 0.        , ..., 0.86965174, 0.78764136,
#         0.        ]])

# %%
scaled_data.shape
# Out:
# (7043, 20)

# %% [markdown]
# ### 3.1 Train Test Split

# %%
data5 = data4.copy()

X = data5.drop('Churn', axis=1)
y = data5['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Print the shapes of the training and testing sets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (5282, 19), y_train shape: (5282,)
# X_test shape: (1761, 19), y_test shape: (1761,)

# %% [markdown]
# ### 3.2 PyCaret to find the suitable algorithm

# %%
#Initialize the environment
setup(data4, target='Churn')

# Compare models
best_model = compare_models()

# Create a model
model = create_model(best_model)

# Evaluate the model
plot_model(model)
# Out:
# <style type="text/css">
# #T_9dff1_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9dff1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9dff1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9dff1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dff1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9dff1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9dff1_row0_col1" class="data row0 col1" >8540</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9dff1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9dff1_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9dff1_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9dff1_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9dff1_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9dff1_row3_col1" class="data row3 col1" >(7043, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9dff1_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9dff1_row4_col1" class="data row4 col1" >(7043, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9dff1_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9dff1_row5_col1" class="data row5 col1" >(4930, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9dff1_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9dff1_row6_col1" class="data row6 col1" >(2113, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9dff1_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9dff1_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9dff1_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_9dff1_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9dff1_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_9dff1_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9dff1_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_9dff1_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9dff1_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_9dff1_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9dff1_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_9dff1_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9dff1_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_9dff1_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9dff1_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_9dff1_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9dff1_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_9dff1_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9dff1_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_9dff1_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9dff1_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_9dff1_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9dff1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9dff1_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_9dff1_row18_col1" class="data row18 col1" >59b2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d2489 th {
#   text-align: left;
# }
# #T_d2489_row0_col0, #T_d2489_row0_col3, #T_d2489_row0_col4, #T_d2489_row0_col5, #T_d2489_row1_col0, #T_d2489_row1_col1, #T_d2489_row1_col2, #T_d2489_row1_col3, #T_d2489_row1_col5, #T_d2489_row1_col6, #T_d2489_row1_col7, #T_d2489_row2_col0, #T_d2489_row2_col1, #T_d2489_row2_col2, #T_d2489_row2_col3, #T_d2489_row2_col4, #T_d2489_row2_col5, #T_d2489_row2_col6, #T_d2489_row2_col7, #T_d2489_row3_col0, #T_d2489_row3_col1, #T_d2489_row3_col2, #T_d2489_row3_col3, #T_d2489_row3_col4, #T_d2489_row3_col5, #T_d2489_row3_col6, #T_d2489_row3_col7, #T_d2489_row4_col0, #T_d2489_row4_col1, #T_d2489_row4_col2, #T_d2489_row4_col3, #T_d2489_row4_col4, #T_d2489_row4_col5, #T_d2489_row4_col6, #T_d2489_row4_col7, #T_d2489_row5_col0, #T_d2489_row5_col1, #T_d2489_row5_col2, #T_d2489_row5_col3, #T_d2489_row5_col4, #T_d2489_row5_col5, #T_d2489_row5_col6, #T_d2489_row5_col7, #T_d2489_row6_col0, #T_d2489_row6_col1, #T_d2489_row6_col2, #T_d2489_row6_col3, #T_d2489_row6_col4, #T_d2489_row6_col5, #T_d2489_row6_col6, #T_d2489_row6_col7, #T_d2489_row7_col0, #T_d2489_row7_col1, #T_d2489_row7_col2, #T_d2489_row7_col3, #T_d2489_row7_col4, #T_d2489_row7_col5, #T_d2489_row7_col6, #T_d2489_row7_col7, #T_d2489_row8_col0, #T_d2489_row8_col1, #T_d2489_row8_col2, #T_d2489_row8_col3, #T_d2489_row8_col4, #T_d2489_row8_col5, #T_d2489_row8_col6, #T_d2489_row8_col7, #T_d2489_row9_col0, #T_d2489_row9_col1, #T_d2489_row9_col2, #T_d2489_row9_col3, #T_d2489_row9_col4, #T_d2489_row9_col5, #T_d2489_row9_col6, #T_d2489_row9_col7, #T_d2489_row10_col0, #T_d2489_row10_col1, #T_d2489_row10_col2, #T_d2489_row10_col4, #T_d2489_row10_col6, #T_d2489_row10_col7, #T_d2489_row11_col0, #T_d2489_row11_col1, #T_d2489_row11_col2, #T_d2489_row11_col3, #T_d2489_row11_col4, #T_d2489_row11_col5, #T_d2489_row11_col6, #T_d2489_row11_col7, #T_d2489_row12_col0, #T_d2489_row12_col1, #T_d2489_row12_col2, #T_d2489_row12_col3, #T_d2489_row12_col4, #T_d2489_row12_col5, #T_d2489_row12_col6, #T_d2489_row12_col7, #T_d2489_row13_col0, #T_d2489_row13_col1, #T_d2489_row13_col2, #T_d2489_row13_col3, #T_d2489_row13_col4, #T_d2489_row13_col5, #T_d2489_row13_col6, #T_d2489_row13_col7, #T_d2489_row14_col0, #T_d2489_row14_col1, #T_d2489_row14_col2, #T_d2489_row14_col3, #T_d2489_row14_col4, #T_d2489_row14_col5, #T_d2489_row14_col6, #T_d2489_row14_col7 {
#   text-align: left;
# }
# #T_d2489_row0_col1, #T_d2489_row0_col2, #T_d2489_row0_col6, #T_d2489_row0_col7, #T_d2489_row1_col4, #T_d2489_row10_col3, #T_d2489_row10_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d2489_row0_col8, #T_d2489_row1_col8, #T_d2489_row2_col8, #T_d2489_row3_col8, #T_d2489_row4_col8, #T_d2489_row5_col8, #T_d2489_row6_col8, #T_d2489_row7_col8, #T_d2489_row8_col8, #T_d2489_row9_col8, #T_d2489_row11_col8, #T_d2489_row12_col8, #T_d2489_row13_col8, #T_d2489_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d2489_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d2489" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2489_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d2489_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d2489_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d2489_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d2489_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d2489_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d2489_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d2489_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d2489_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2489_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_d2489_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_d2489_row0_col1" class="data row0 col1" >0.8045</td>
#       <td id="T_d2489_row0_col2" class="data row0 col2" >0.8465</td>
#       <td id="T_d2489_row0_col3" class="data row0 col3" >0.5634</td>
#       <td id="T_d2489_row0_col4" class="data row0 col4" >0.6536</td>
#       <td id="T_d2489_row0_col5" class="data row0 col5" >0.6046</td>
#       <td id="T_d2489_row0_col6" class="data row0 col6" >0.4757</td>
#       <td id="T_d2489_row0_col7" class="data row0 col7" >0.4784</td>
#       <td id="T_d2489_row0_col8" class="data row0 col8" >0.6900</td>
#     </tr>
#     <tr>
#       <th id="T
td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78fe9_row6_col0" class="data row6 col0" >0.8377</td>
#       <td id="T_78fe9_row6_col1" class="data row6 col1" >0.8605</td>
#       <td id="T_78fe9_row6_col2" class="data row6 col2" >0.6260</td>
#       <td id="T_78fe9_row6_col3" class="data row6 col3" >0.7257</td>
#       <td id="T_78fe9_row6_col4" class="data row6 col4" >0.6721</td>
#       <td id="T_78fe9_row6_col5" class="data row6 col5" >0.5651</td>
#       <td id="T_78fe9_row6_col6" class="data row6 col6" >0.5678</td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78fe9_row7_col0" class="data row7 col0" >0.8235</td>
#       <td id="T_78fe9_row7_col1" class="data row7 col1" >0.8690</td>
#       <td id="T_78fe9_row7_col2" class="data row7 col2" >0.5878</td>
#       <td id="T_78fe9_row7_col3" class="data row7 col3" >0.7000</td>
#       <td id="T_78fe9_row7_col4" class="data row7 col4" >0.6390</td>
#       <td id="T_78fe9_row7_col5" class="data row7 col5" >0.5234</td>
#       <td id="T_78fe9_row7_col6" class="data row7 col6" >0.5269</td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78fe9_row8_col0" class="data row8 col0" >0.8012</td>
#       <td id="T_78fe9_row8_col1" class="data row8 col1" >0.8463</td>
#       <td id="T_78fe9_row8_col2" class="data row8 col2" >0.5954</td>
#       <td id="T_78fe9_row8_col3" class="data row8 col3" >0.6341</td>
#       <td id="T_78fe9_row8_col4" class="data row8 col4" >0.6142</td>
#       <td id="T_78fe9_row8_col5" class="data row8 col5" >0.4805</td>
#       <td id="T_78fe9_row8_col6" class="data row8 col6" >0.4809</td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78fe9_row9_col0" class="data row9 col0" >0.7850</td>
#       <td id="T_78fe9_row9_col1" class="data row9 col1" >0.8280</td>
#       <td id="T_78fe9_row9_col2" class="data row9 col2" >0.5191</td>
#       <td id="T_78fe9_row9_col3" class="data row9 col3" >0.6126</td>
#       <td id="T_78fe9_row9_col4" class="data row9 col4" >0.5620</td>
#       <td id="T_78fe9_row9_col5" class="data row9 col5" >0.4208</td>
#       <td id="T_78fe9_row9_col6" class="data row9 col6" >0.4233</td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_78fe9_row10_col0" class="data row10 col0" >0.8045</td>
#       <td id="T_78fe9_row10_col1" class="data row10 col1" >0.8465</td>
#       <td id="T_78fe9_row10_col2" class="data row10 col2" >0.5634</td>
#       <td id="T_78fe9_row10_col3" class="data row10 col3" >0.6536</td>
#       <td id="T_78fe9_row10_col4" class="data row10 col4" >0.6046</td>
#       <td id="T_78fe9_row10_col5" class="data row10 col5" >0.4757</td>
#       <td id="T_78fe9_row10_col6" class="data row10 col6" >0.4784</td>
#     </tr>
#     <tr>
#       <th id="T_78fe9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_78fe9_row11_col0" class="data row11 col0" >0.0164</td>
#       <td id="T_78fe9_row11_col1" class="data row11 col1" >0.0130</td>
#       <td id="T_78fe9_row11_col2" class="data row11 col2" >0.0315</td>
#       <td id="T_78fe9_row11_col3" class="data row11 col3" >0.0410</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### 3.3 HyperParemeter --- Tunning using Optuna

# %%
# Define the objective function to optimize
def objective(trial):
    # Define the hyperparameters to optimize
    n_estimators = trial.suggest_int('n_estimators', 50, 500)
    learning_rate = trial.suggest_float('learning_rate', 0.1, 1.0)
    


    # Create a AdaBoostClassifier with the specified hyperparameters
    model = AdaBoostClassifier(n_estimators=n_estimators, learning_rate = learning_rate, random_state=42)

    # Fit the model on the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = model.predict(X_test)

    # Calculate the accuracy score of the model
    accuracy = accuracy_score(y_test, y_pred)

    # Return the accuracy score as the objective value
    return accuracy

# Create an Optuna study object and optimize the objective function
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# Print the best hyperparameters and the corresponding accuracy score
print(f'Best hyperparameters: {study.best_params}')
print(f'Best accuracy: {study.best_value}')
# Out:
# [I 2023-05-09 18:09:48,536] A new study created in memory with name: no-name-b55b7b8f-1e31-4713-bd31-768e5e995657
# [I 2023-05-09 18:09:51,391] Trial 0 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 385, 'learning_rate': 0.7295272746053891}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:09:52,291] Trial 1 finished with value: 0.8029528676888131 and parameters: {'n_estimators': 111, 'learning_rate': 0.8544487267732942}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:09:53,217] Trial 2 finished with value: 0.7989778534923339 and parameters: {'n_estimators': 140, 'learning_rate': 0.23693719565422924}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:09:57,773] Trial 3 finished with value: 0.8035207268597387 and parameters: {'n_estimators': 469, 'learning_rate': 0.3963524118341972}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:09:58,411] Trial 4 finished with value: 0.7989778534923339 and parameters: {'n_estimators': 50, 'learning_rate': 0.38509661555635577}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:01,816] Trial 5 finished with value: 0.8029528676888131 and parameters: {'n_estimators': 157, 'learning_rate': 0.7795152192557311}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:10,485] Trial 6 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 496, 'learning_rate': 0.8520282099552267}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:12,488] Trial 7 finished with value: 0.8035207268597387 and parameters: {'n_estimators': 187, 'learning_rate': 0.4050288524672381}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:17,701] Trial 8 finished with value: 0.8040885860306644 and parameters: {'n_estimators': 473, 'learning_rate': 0.9878735999592171}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:22,096] Trial 9 finished with value: 0.80465644520159 and parameters: {'n_estimators': 476, 'learning_rate': 0.5084811275092866}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:24,721] Trial 10 finished with value: 0.80465644520159 and parameters: {'n_estimators': 333, 'learning_rate': 0.6649540480323116}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:26,892] Trial 11 finished with value: 0.8040885860306644 and parameters: {'n_estimators': 356, 'learning_rate': 0.6867345531137529}. Best is trial 0 with value: 0.8052243043725156.
# [I 2023-05-09 18:10:29,191] Trial 12 finished with value: 0.8086314593980692 and parameters: {'n_estimators': 373, 'learning_rate': 0.9213289715889023}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:31,553] Trial 13 finished with value: 0.80465644520159 and parameters: {'n_estimators': 380, 'learning_rate': 0.9838770781569921}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:33,241] Trial 14 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 271, 'learning_rate': 0.6638324916518428}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:36,705] Trial 15 finished with value: 0.8080636002271436 and parameters: {'n_estimators': 415, 'learning_rate': 0.8350529147922632}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:39,361] Trial 16 finished with value: 0.8035207268597387 and parameters: {'n_estimators': 276, 'learning_rate': 0.8924460458564628}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:42,303] Trial 17 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 416, 'learning_rate': 0.7849872143881542}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:44,101] Trial 18 finished with value: 0.8069278818852924 and parameters: {'n_estimators': 298, 'learning_rate': 0.9170251196056061}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:46,609] Trial 19 finished with value: 0.8057921635434412 and parameters: {'n_estimators': 423, 'learning_rate': 0.7983506244914607}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:48,554] Trial 20 finished with value: 0.8069278818852924 and parameters: {'n_estimators': 328, 'learning_rate': 0.9992418313901372}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:50,264] Trial 21 finished with value: 0.8029528676888131 and parameters: {'n_estimators': 277, 'learning_rate': 0.9040469004388859}. Best is trial 12 with value: 0.8086314593980692.
# [I 2023-05-09 18:10:52,298] Trial 22 finished with value: 0.8091993185689949 and parameters: {'n_estimators': 233, 'learning_rate': 0.9162907154693313}. Best is trial 22 with value: 0.8091993185689949.
# [I 2023-05-09 18:10:54,361] Trial 23 finished with value: 0.8086314593980692 and parameters: {'n_estimators':
. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:26,835] Trial 82 finished with value: 0.8097671777399205 and parameters: {'n_estimators': 263, 'learning_rate': 0.9437522507285823}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:28,128] Trial 83 finished with value: 0.80465644520159 and parameters: {'n_estimators': 218, 'learning_rate': 0.894458729399887}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:29,591] Trial 84 finished with value: 0.807495741056218 and parameters: {'n_estimators': 246, 'learning_rate': 0.966104010979415}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:31,650] Trial 85 finished with value: 0.8018171493469619 and parameters: {'n_estimators': 228, 'learning_rate': 0.8669629989796009}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:33,243] Trial 86 finished with value: 0.807495741056218 and parameters: {'n_estimators': 178, 'learning_rate': 0.9272850045859868}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:35,071] Trial 87 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 202, 'learning_rate': 0.9821833031919469}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:37,011] Trial 88 finished with value: 0.8086314593980692 and parameters: {'n_estimators': 268, 'learning_rate': 0.8303102864489467}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:38,444] Trial 89 finished with value: 0.8086314593980692 and parameters: {'n_estimators': 241, 'learning_rate': 0.9406848714121876}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:39,230] Trial 90 finished with value: 0.8069278818852924 and parameters: {'n_estimators': 127, 'learning_rate': 0.9109572154692557}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:40,517] Trial 91 finished with value: 0.8057921635434412 and parameters: {'n_estimators': 218, 'learning_rate': 0.956482327846446}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:41,778] Trial 92 finished with value: 0.8057921635434412 and parameters: {'n_estimators': 213, 'learning_rate': 0.9287405546050872}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:43,127] Trial 93 finished with value: 0.8029528676888131 and parameters: {'n_estimators': 227, 'learning_rate': 0.8757036403667552}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:44,628] Trial 94 finished with value: 0.8080636002271436 and parameters: {'n_estimators': 255, 'learning_rate': 0.9877108524861403}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:45,896] Trial 95 finished with value: 0.80465644520159 and parameters: {'n_estimators': 209, 'learning_rate': 0.894829391855981}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:47,531] Trial 96 finished with value: 0.8069278818852924 and parameters: {'n_estimators': 192, 'learning_rate': 0.9543009369044699}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:49,133] Trial 97 finished with value: 0.8052243043725156 and parameters: {'n_estimators': 175, 'learning_rate': 0.8537966679129456}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:51,266] Trial 98 finished with value: 0.8080636002271436 and parameters: {'n_estimators': 236, 'learning_rate': 0.9281724024837835}. Best is trial 26 with value: 0.8126064735945485.
# [I 2023-05-09 18:12:53,210] Trial 99 finished with value: 0.8057921635434412 and parameters: {'n_estimators': 260, 'learning_rate': 0.9010079313352457}. Best is trial 26 with value: 0.8126064735945485.
# Best hyperparameters: {'n_estimators': 235, 'learning_rate': 0.9361334370728983}
# Best accuracy: 0.8126064735945485

# %%
"""print(f'Best hyperparameters: {study.best_params}')
print(f'Best accuracy: {study.best_value}')"""
# Out:
# "print(f'Best hyperparameters: {study.best_params}')\nprint(f'Best accuracy: {study.best_value}')"

# %% [markdown]
# ### 3.4 Training model with the best parameter from the above result

# %%
# Create a AdaBoostClassifier with the specified hyperparameters
model = AdaBoostClassifier(n_estimators= 211, learning_rate = 0.9434598854481292, random_state=42)

# Fit the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the accuracy score of the model
accuracy = accuracy_score(y_test, y_pred)

# Return the accuracy score as the objective value
accuracy
# Out:
# 0.8120386144236229

# %% [markdown]
# ### 3.5 Saving Model to file

# %%
# Specify the path and filename of the new file location
new_file_location = '/content/gdrive/MyDrive/Telco Customer Churn/model/adaModel.pki'

# Save the model to the new file location using pickle
with open(new_file_location, 'wb') as f:
    pickle.dump(model, f)

# Close the file
f.close()
